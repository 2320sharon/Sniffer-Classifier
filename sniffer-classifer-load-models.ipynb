# %% [markdown]
# ## Load Sniffer Classifier Models

# %%
import os
import pandas as pd

import tensorflow as tf
from tensorflow import keras

from sklearn.metrics import confusion_matrix
import seaborn as sns

# %% [markdown]
# ## Local Variables
# - `model_path` : Directory location of the models
# - `model_name` : Name of folder containing the model to load

# %%
model_name="model_100_x_100"
model_path=os.getcwd()+ os.sep+"models"+os.sep+model_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21296\1070874438.py in <module>
#       1 model_name="model_100_x_100"
#       2 model_path=os.getcwd()+ os.sep+"models"+os.sep+model_name
# ----> 3 new_model = tf.keras.models.load_model(model_path+os.sep+"model")
#       4 new_model.summary()
#
# NameError: name 'tf' is not defined

# %% [markdown]
# ## Load Metrics, Model.Summary for an old model

# %%
df=pd.read_csv(model_path+os.sep+"model_metrics.csv")
df
# Out:
#         loss     tp    fp     tn    fn  accuracy  precision  recall       AUC  \
# 0   0.145390  380.0  20.0  380.0  20.0   0.05500     0.9500  0.9500  0.983306
# 1   0.150853  381.0  19.0  381.0  19.0   0.05500     0.9525  0.9525  0.982513
# 2   0.145436  380.0  20.0  380.0  20.0   0.04625     0.9500  0.9500  0.986181
# 3   0.170459  381.0  19.0  381.0  19.0   0.04500     0.9525  0.9525  0.974381
# 4   0.144483  386.0  14.0  386.0  14.0   0.05250     0.9650  0.9650  0.979738
# 5   0.156334  383.0  17.0  383.0  17.0   0.05375     0.9575  0.9575  0.980825
# 6   0.163277  382.0  18.0  382.0  18.0   0.04000     0.9550  0.9550  0.976469
# 7   0.122142  382.0  18.0  382.0  18.0   0.04625     0.9550  0.9550  0.989844
# 8   0.158700  382.0  18.0  382.0  18.0   0.05375     0.9550  0.9550  0.978588
# 9   0.148646  384.0  16.0  384.0  16.0   0.05875     0.9600  0.9600  0.986009
# 10  0.125969  386.0  14.0  386.0  14.0   0.06500     0.9650  0.9650  0.986225
# ...

# %%
new_model = tf.keras.models.load_model(model_path+os.sep+"model")
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 98, 98, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 49, 49, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 47, 47, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 23, 23, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 21, 21, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 10, 10, 32)       0
#  2D)
#
#  dropout (Dropout)           (None, 10, 10, 32)        0
#
#  flatten (Flatten)           (None, 3200)              0
#
#  dense (Dense)               (None, 16)                51216
#
#  dense_1 (Dense)             (None, 2)                 34
#
# ...
# Total params: 70,642
# Trainable params: 70,642
# Non-trainable params: 0
# _________________________________________________________________
